# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv("product_data.csv")
ds
# Out:
#      CustomerID     Product                Price Quantity       City  \
# 0          1052     Desktop                  NaN      4.0  Bangalore
# 1          1041     Desktop                  NaN      3.0      Delhi
# 2          1057  Smartphone  forty-five thousand      2.0  Bangalore
# 3          1038      Tablet              45000.0      1.0    Chennai
# 4          1013  Smartphone              45000.0      NaN     Mumbai
# ..          ...         ...                  ...      ...        ...
# 120        1074      Laptop              45000.0      NaN  Bangalore
# 121        1017     Desktop              45000.0      NaN       Pune
# 122        1075     Desktop              30000.0      1.0       Pune
# 123        1008      Laptop              60000.0      1.0    Chennai
# 124        1073      Laptop              15000.0      NaN      Delhi
#
#     PurchaseDate
# 0     2021-06-30
# 1     2023-01-21
# 2     2023-04-06
# 3     2023-07-05
# 4     2022-04-11
# ..           ...
# ...

# %%
print(ds.to_string())
# Out:
#      CustomerID     Product                Price Quantity       City PurchaseDate
# 0          1052     Desktop                  NaN      4.0  Bangalore   2021-06-30
# 1          1041     Desktop                  NaN      3.0      Delhi   2023-01-21
# 2          1057  Smartphone  forty-five thousand      2.0  Bangalore   2023-04-06
# 3          1038      Tablet              45000.0      1.0    Chennai   2023-07-05
# 4          1013  Smartphone              45000.0      NaN     Mumbai   2022-04-11
# 5          1094      Laptop              60000.0      two     Mumbai   2022-03-12
# 6          1004      Laptop              30000.0      2.0    Chennai   2022-02-25
# 7          1034      Laptop              30000.0      2.0    Chennai   2022-12-22
# 8          1086      Laptop              30000.0      3.0      Delhi   2022-10-23
# 9          1092     Desktop              30000.0      3.0     Mumbai   2022-03-12
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    125 non-null    int64
#  1   Product       125 non-null    object
#  2   Price         103 non-null    object
#  3   Quantity      98 non-null     object
#  4   City          125 non-null    object
#  5   PurchaseDate  125 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 6.0+ KB

# %%
ds.loc[2,'Price']=45000
ds.loc[5,'Quantity']=2

# %%
ds['Price']=pd.to_numeric(ds['Price'])
ds['Quantity']=pd.to_numeric(ds['Quantity'])

# %%
ds['PurchaseDate']=pd.to_datetime(ds['PurchaseDate'])

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    125 non-null    int64
#  1   Product       125 non-null    object
#  2   Price         103 non-null    float64
#  3   Quantity      98 non-null     float64
#  4   City          125 non-null    object
#  5   PurchaseDate  125 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 6.0+ KB

# %%
x=ds['Price'].mean()
ds['Price'].fillna(x,inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    125 non-null    int64
#  1   Product       125 non-null    object
#  2   Price         125 non-null    float64
#  3   Quantity      98 non-null     float64
#  4   City          125 non-null    object
#  5   PurchaseDate  125 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 6.0+ KB

# %%
x=ds['Quantity'].median()
ds['Quantity'].fillna(x,inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    125 non-null    int64
#  1   Product       125 non-null    object
#  2   Price         125 non-null    float64
#  3   Quantity      125 non-null    float64
#  4   City          125 non-null    object
#  5   PurchaseDate  125 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 6.0+ KB

# %%
print(ds.to_string())
# Out:
#      CustomerID     Product         Price  Quantity       City PurchaseDate
# 0          1052     Desktop  36262.135922       4.0  Bangalore   2021-06-30
# 1          1041     Desktop  36262.135922       3.0      Delhi   2023-01-21
# 2          1057  Smartphone  45000.000000       2.0  Bangalore   2023-04-06
# 3          1038      Tablet  45000.000000       1.0    Chennai   2023-07-05
# 4          1013  Smartphone  45000.000000       2.5     Mumbai   2022-04-11
# 5          1094      Laptop  60000.000000       2.0     Mumbai   2022-03-12
# 6          1004      Laptop  30000.000000       2.0    Chennai   2022-02-25
# 7          1034      Laptop  30000.000000       2.0    Chennai   2022-12-22
# 8          1086      Laptop  30000.000000       3.0      Delhi   2022-10-23
# 9          1092     Desktop  30000.000000       3.0     Mumbai   2022-03-12
# 10         1074      Laptop  45000.000000       2.5  Bangalore   2021-08-14
# ...

# %%
ds['Price']=ds['Price'].round(2)
ds['Quantity']=ds['Quantity'].round(0)

# %%
print(ds.to_string())
# Out:
#      CustomerID     Product     Price  Quantity       City PurchaseDate
# 0          1052     Desktop  36262.14       4.0  Bangalore   2021-06-30
# 1          1041     Desktop  36262.14       3.0      Delhi   2023-01-21
# 2          1057  Smartphone  45000.00       2.0  Bangalore   2023-04-06
# 3          1038      Tablet  45000.00       1.0    Chennai   2023-07-05
# 4          1013  Smartphone  45000.00       2.0     Mumbai   2022-04-11
# 5          1094      Laptop  60000.00       2.0     Mumbai   2022-03-12
# 6          1004      Laptop  30000.00       2.0    Chennai   2022-02-25
# 7          1034      Laptop  30000.00       2.0    Chennai   2022-12-22
# 8          1086      Laptop  30000.00       3.0      Delhi   2022-10-23
# 9          1092     Desktop  30000.00       3.0     Mumbai   2022-03-12
# 10         1074      Laptop  45000.00       2.0  Bangalore   2021-08-14
# 11         1017     Desktop  45000.00       2.0       Pune   2022-08-09
# ...

# %%
ds['Quantity']=ds['Quantity'].astype(int)

# %%
print(ds.to_string())
# Out:
#      CustomerID     Product     Price  Quantity       City PurchaseDate
# 0          1052     Desktop  36262.14         4  Bangalore   2021-06-30
# 1          1041     Desktop  36262.14         3      Delhi   2023-01-21
# 2          1057  Smartphone  45000.00         2  Bangalore   2023-04-06
# 3          1038      Tablet  45000.00         1    Chennai   2023-07-05
# 4          1013  Smartphone  45000.00         2     Mumbai   2022-04-11
# 5          1094      Laptop  60000.00         2     Mumbai   2022-03-12
# 6          1004      Laptop  30000.00         2    Chennai   2022-02-25
# 7          1034      Laptop  30000.00         2    Chennai   2022-12-22
# 8          1086      Laptop  30000.00         3      Delhi   2022-10-23
# 9          1092     Desktop  30000.00         3     Mumbai   2022-03-12
# 10         1074      Laptop  45000.00         2  Bangalore   2021-08-14
# 11         1017     Desktop  45000.00         2       Pune   2022-08-09
# ...

# %%
ds.to_csv("Cleaned_data_pr2.csv",index=False)
